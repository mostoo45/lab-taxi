# %%
from agent import Agent
from monitor import interact
import gym
import numpy as np
import matplotlib.pyplot as plt

# %%
env = gym.make('Taxi-v2')
agent = Agent()
avg_rewards, best_avg_reward = interact(env, agent)

plt.figure(figsize=(20, 10))
plt.plot(avg_rewards)
plt.show()
# Out:
# Episode 27/20000 || Best average reward -inf
# /home/sungmok/udacity/gym/gym/__init__.py:22: UserWarning: DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.
#   warnings.warn('DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.')
# Episode 20000/20000 || Best average reward 9.492
